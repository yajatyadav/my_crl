# %%
print("hi")
# Out:
# Running cells with 'my-crl (3.11.7) (Python 3.11.7)' requires the ipykernel package.
#
# Install 'ipykernel' into the Python environment.
#
# Command: '"/Users/yajatyadav/Su26/self learning/my_CRL/.venv/bin/python" -m pip install ipykernel -U --force-reinstall'
